# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 
import random 
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader,random_split
from torch import nn
import torch.nn.functional as F
import torch.optim as optim

# %%
torch.cuda.empty_cache()

# %%
import AECompare.util as u
import AECompare.autoencoder as ae
util = u.Util()
train_data = util.get_sep_indx_data(digit_filter=0)

# %%
VAE = ae.VariationalAutoEncoder(latent_len=2, digit=0)

# %%
# Fit will also store the model
VAE.fit(train_data, num_epochs=100, lr=0.001, batch_size=64)
# Out:
# Epoch 1, train loss: 80.42647744030158
# Epoch 2, train loss: 64.76020093972913
# Epoch 3, train loss: 62.138710291184786
# Epoch 4, train loss: 61.26746341229371
# Epoch 5, train loss: 59.69392918759497
# Epoch 6, train loss: 58.975244767155054
# Epoch 7, train loss: 58.19450130845855
# Epoch 8, train loss: 58.008295051797546
# Epoch 9, train loss: 57.4611999006785
# Epoch 10, train loss: 56.662892764270374
# Epoch 11, train loss: 56.728767762126985
# Epoch 12, train loss: 56.10761560468723
# Epoch 13, train loss: 55.91916340266493
# Epoch 14, train loss: 55.8677589819678
# Epoch 15, train loss: 55.40855140563666
# Epoch 16, train loss: 55.25868282031514
# Epoch 17, train loss: 55.114320341847986
# Epoch 18, train loss: 54.95660558053615
# Epoch 19, train loss: 55.061198631130765
# Epoch 20, train loss: 54.70618108581615
# Epoch 21, train loss: 54.42067655517949
# Epoch 22, train loss: 54.348082393483296
# Epoch 23, train loss: 53.95254739699846
# ...

# %%
VAE.load_state_dict(torch.load('AECompare/MNIST_digits_models/0_model_2.pth'))
# Out:
# <All keys matched successfully>

# %%
test_data = util.get_sep_indx_data(digit_filter=0, train=False)
test_loss, latent = VAE.test(test_data)
VAE.store_latent(latent)

# %%
VAE.evaluate(test_data)
